# %% [markdown]
# <a href="https://colab.research.google.com/github/parthn369/Sentiment-Analysis/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.amazon.in/OnePlus-Nord-Marble-128GB-Storage/product-reviews/B086977J3K/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
names = soup.select("span.a-profile-name")[2:]
names
# Out:
# [<span class="a-profile-name">Abhishek Agarwal</span>,
#  <span class="a-profile-name">Kiran KS</span>,
#  <span class="a-profile-name">Aman More</span>,
#  <span class="a-profile-name">Nikhil</span>,
#  <span class="a-profile-name">Deblina Roy</span>,
#  <span class="a-profile-name">Sreeram</span>,
#  <span class="a-profile-name">Nitin Mittal</span>,
#  <span class="a-profile-name">Amit</span>,
#  <span class="a-profile-name">aishwarya</span>,
#  <span class="a-profile-name">Sudeshna Dey</span>]

# %%
stars = soup.select("span.a-icon-alt")[3:]
stars
# Out:
# [<span class="a-icon-alt">3.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">2.0 out of 5 stars</span>,
#  <span class="a-icon-alt">1.0 out of 5 stars</span>,
#  <span class="a-icon-alt">1.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">1.0 out of 5 stars</span>]

# %%
title = soup.select("a.review-title-content span")
title
# Out:
# [<span>Bad bad camera</span>,
#  <span>The original segment of One Plus</span>,
#  <span>A good daily driver.</span>,
#  <span>*Read before you buy!!*</span>,
#  <span>Disappointing</span>,
#  <span>Totally dissatisfied. No AR support.</span>,
#  <span>Empty mobile box with all.missomg contents was delivered</span>,
#  <span>Near to mid range  Perfection</span>,
#  <span>Great price!</span>,
#  <span>Bad front camera</span>]

# %%
dates = soup.select("span.review-date")[2:]
dates
# Out:
# [<span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 2 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 3 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 3 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 4 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 4 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 3 August 2020</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 30 August 2020</span>,
# ...

# %%
desc = soup.select("span.review-text-content span")
desc
# Out:
# [<span>
#    It's not very often I leave a critical review for any product. But i was so excited when my new OnePlus Nord got delivered to me earlier today, ahead of time. While i am still exploring the phone, the one aspect that is a complete let down is the camera. The pics I clicked were grainy and so not cool. I must say oneplus, you guys really turned me off this time, like honestly. Most phones these days look and feel alike with the camera being one aspect that sets the winners apart from ordinary phones...i dont know what you guys did here. Not expected team OnePlus...this is just not you. My Poco F1 that i purchased 2 years back returned 10 times better pics. Since i cant return this item, I'm going to live with this for a while before i upgrade. I am sorry for the negative review.
#  </span>, <span>
# ...

# %%
cust_name = []
ratings = []
rev_title = []
rev_date = []
rev_desc = []
for i in range(len(names)):
 cust_name.append(names[i].get_text())
 ratings.append(stars[i].get_text()[:3])
 rev_title.append(title[i].get_text())
 rev_date.append(dates[i].get_text().replace("Reviewed in India on",""))
 rev_desc.append(desc[i].get_text().strip("\n "))

# %%
rev_desc
# Out:
# ["It's not very often I leave a critical review for any product. But i was so excited when my new OnePlus Nord got delivered to me earlier today, ahead of time. While i am still exploring the phone, the one aspect that is a complete let down is the camera. The pics I clicked were grainy and so not cool. I must say oneplus, you guys really turned me off this time, like honestly. Most phones these days look and feel alike with the camera being one aspect that sets the winners apart from ordinary phones...i dont know what you guys did here. Not expected team OnePlus...this is just not you. My Poco F1 that i purchased 2 years back returned 10 times better pics. Since i cant return this item, I'm going to live with this for a while before i upgrade. I am sorry for the negative review.",
# ...

# %%
import pandas as pd
df = pd.DataFrame()
df['Date'] = rev_date
df['Name'] = cust_name
df['Ratings'] = ratings
df['Title'] = rev_title
df['Description'] = rev_desc
df
# Out:
#               Date  ...                                        Description
# 0    2 August 2020  ...  It's not very often I leave a critical review ...
# 1    3 August 2020  ...  Battery usage update: Drains faster than other...
# 2    3 August 2020  ...  Pros:1) Clean and bloatfree OxygenOS, which ru...
# 3    4 August 2020  ...  Yea..pre-ordered on 28 July, got it on 4 Augus...
# 4    4 August 2020  ...  Heavily disappointed. So much of hype and the ...
# 5    3 August 2020  ...  I bought this phone for augmented reality purp...
# 6   30 August 2020  ...   Stop cheating customers by arranging a temper...
# 7    3 August 2020  ...  Got it delivered yesterday , used for about 5-...
# 8    4 August 2020  ...  An amazing phone!Got it delivered today and al...
# 9    3 August 2020  ...  Front camera is very bad , and low light photo...
#
# [10 rows x 5 columns]

# %%
df.to_csv("reviews.csv")

# %%
cust_name = []
ratings = []
rev_title = []
rev_date = []
rev_desc = []
error = []
for i in range (1,51):
  url = "https://www.amazon.in/OnePlus-Nord-Marble-128GB-Storage/product-reviews/B086977J3K/ref=cm_cr_arp_d_viewpnt_lft?ie=UTF8&reviewerType=all_reviews&filterByStar=positive&pageNumber="+ str(i)
  page = requests.get(url)
  if str(page)[11:14] == 200:
    soup = BeautifulSoup(page.content, 'html.parser')
    names = soup.select("span.a-profile-name")[2:]
    stars = soup.select("span.a-icon-alt")[3:]
    title = soup.select("a.review-title-content span")
    dates = soup.select("span.review-date")[2:]
    desc = soup.select("span.review-text-content span")
    for j in range (len(names)):
     cust_name.append(names[i].get_text())
     ratings.append(stars[i].get_text()[:3])
     rev_title.append(title[i].get_text())
     rev_date.append(dates[i].get_text().replace("Reviewed in India on",""))
     rev_desc.append(desc[i].get_text().strip("\n "))
  else:
    error.append(i)
